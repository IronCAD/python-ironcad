# %%
from core import IronCAD
import inspect

# %% [markdown]
# # Attach to IRONCAD and get baseapp

# %%
IRONCAD = IronCAD()
# attach process
IRONCAD.attach()

IZBaseApp = IRONCAD.get_baseapp()

# %%
# print methods for base app interface
help(IZBaseApp)

# %% [markdown]
# ## create array of catalogs

# %%
# get and print all catalogs
CatalogMgr = IZBaseApp.CatalogMgr

cat_iter = 0
catalogs = []
while True:
    try:
        catalogs.append(CatalogMgr.Catalog(cat_iter))
        cat_iter += 1
    except Exception as e:
        break

print(len(catalogs))
# Out:
# 8

# %%
# print methods for catalog interface
help(catalogs[0])

# %% [markdown]
# ### Print All Open Catalogs

# %%
for i in catalogs:
    print(i.Name)
# Out:
# ICM Mech
# ICM Tools
# ICM Utils
# ICM Pipes
# ICM Flanges
# ICM Mold
# RePak-P
# Starter

# %% [markdown]
# ## Select a specific catalog

# %%
SELECTED_CATALOG_NAME = "Starter"
SELECTED_CATALOG = None
for i in catalogs:
    if i.Name == SELECTED_CATALOG_NAME:
        SELECTED_CATALOG = i
        break
if SELECTED_CATALOG is None:
    raise ValueError(f"Catalog '{SELECTED_CATALOG_NAME}' not found.")
else:
    print(f"Selected Catalog: {SELECTED_CATALOG.Name}")
# Out:
# Selected Catalog: Starter

# %%
# Activate the selected catalog
SELECTED_CATALOG.Activate()
# Out:
# 0

# %% [markdown]
# ## Create list of catalog entries

# %%
# get and print all entries in catalog

entry_iter = 0
entries = []
while True:
    try:
        entries.append(SELECTED_CATALOG.Entry(entry_iter))
        entry_iter += 1
    except Exception as e:
        break

print(len(entries))
# Out:
# 19

# %%
# Print methods for catalog entry interface
help(entries[0])

# %% [markdown]
# ### print all entries in catalog

# %%
for entry in entries:
    print(entry.Name)
# Out:
# Extrude
# Cut Extrude
# Cylinder
# Cut Cylinder
# Slot
# Cut Slot
# Sphere
# Cut Sphere
# Cut Spin
# Sheet Metal
# Thru Cut Cylinder
# Thru Cut Extrude
# Spin
# Polygons
# Materials
# IC Mech Tools
# Additional Shapes
# Paint
# Training Videos & Resources

# %% [markdown]
# ## Select Entry

# %%
SELECTED_ENTRY_NAME = "Cylinder"
SELECTED_ENTRY = None
for i in entries:
    if i.Name == SELECTED_ENTRY_NAME:
        SELECTED_ENTRY = i
        break
if SELECTED_ENTRY is None:
    raise ValueError(f"Entry '{SELECTED_ENTRY_NAME}' not found.")
else:
    print(f"Selected Entry: {SELECTED_ENTRY.Name}")
# Out:
# Selected Entry: Cylinder

# %% [markdown]
# ## Drop Entry

# %%
SELECTED_ENTRY.InsertElement()
# Out:
# <POINTER(IZElement) ptr=0x1deec46ca48 at 1deef40d250>
